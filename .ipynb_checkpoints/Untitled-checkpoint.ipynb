# %%
pip install fastapi
# Out:
# Requirement already satisfied: fastapi in ./venv/lib/python3.12/site-packages (0.136.0)
# Requirement already satisfied: starlette>=0.46.0 in ./venv/lib/python3.12/site-packages (from fastapi) (1.0.0)
# Requirement already satisfied: pydantic>=2.9.0 in ./venv/lib/python3.12/site-packages (from fastapi) (2.13.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./venv/lib/python3.12/site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.12/site-packages (from fastapi) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./venv/lib/python3.12/site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic>=2.9.0->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in ./venv/lib/python3.12/site-packages (from pydantic>=2.9.0->fastapi) (2.46.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in ./venv/lib/python3.12/site-packages (from starlette>=0.46.0->fastapi) (4.13.0)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (3.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastapi import FastAPI
from pydantic import BaseModel


class dht22(BaseModel):
    temperatura: float
    humedad: float



app = FastAPI()


@app.post("/sensor-data")
async def receive_data(data: dht22):
    print(f" Temp: {data.temperatura}°C  Hum: {data.humedad}%")
    # Aquí puedes guardar en BD, publicar a MQTT, etc.
    return {"status": "ok", "received": data.dict()}
